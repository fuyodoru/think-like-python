# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyodoru/think-like-python/blob/main/CP_Excersises_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
round(42.5)
# Out:
# 42

# %%
round(43.5)
# Out:
# 44

# %%
a=float(input("how many years do you want to convert to seconds?"))
converter = a*365*24*60*60
print(a, "years are", converter, "seconds")
# Out:
# how many years do you want to convert to seconds?1
# 1.0 years are 31536000.0 seconds

# %%
b = float(int(input("how many seconds do you want to conver to years?")))
converter2 = b/(365*24*60*60)
print(b , "seconds are", converter2, "years")
# Out:
# how many seconds do you want to conver to years?1000000000000
# 1000000000000.0 seconds are 31709.791983764586 years

# %%
#name, surname, country, city, street, number, postal code.
name = input("what's your name?")
surname = input("what's your surname?")
country = input("what's the country you live in?")
city = input("which city do you live in?")
street = input("what's the name of your street?")
number = input("what's your house number?")
postal_code = input("what's your postal code?")
print("Your adress is:", name, surname + ",", country + ",", city + ",", street + ",", number + ",", postal_code)
# Out:
# what's your name?asli ezgi
# what's your surname?cil
# what's the country you live in?a
# which city do you live in?a
# what's the name of your street?
# what's your house number?
# what's your postal code?a
# Your adress is: asli ezgi cil, a, a, , , a

# %%
-4
# Out:
# -4

# %%
+2
# Out:
# 2

# %%
2++2
# Out:
# 4

# %%
#765, 2.718, '2 pi', abs(-7), abs(-7.0), abs, int, type
type(abs) #my guess is builtin_function_or_method
type(type) #my guess is type
type(int) #type
# Out:
# type

# %%
#How many seconds are there in 42 minutes 42 seconds?
minutes = int(input("how many minutes do you want to conver to seconds"))
seconds = int(input("how many seconds do you want to conver to seconds"))
total_seconds = (minutes * 60) + seconds
print("There are", total_seconds, "seconds in", minutes, "minutes and", seconds, "seconds.")
# Out:
# how many minutes do you want to conver to seconds42
# how many seconds do you want to conver to seconds42
# There are 2562 seconds in 42 minutes and 42 seconds.

# %%
#How many miles are there in 10 kilometers? Hint: there are 1.61 kilometers in a mile.
km_to_miles = int(input("how many kms do you want to conver to kilometers"))
print(miles, "miles is", (km_to_miles*1.61), "kilometers")
# Out:
# how many kms do you want to conver to kilometers10
# 10 miles is 16.1 kilometers

# %%
#If you run a 10 kilometer race in 42 minutes 42 seconds, what is your average pace in seconds per mile?
# 10 kilometers is approximately 6.21371 miles (10 / 1.61)
distance_miles = 10 / 1.61

# 42 minutes and 42 seconds is 42*60 + 42 = 2562 seconds
time_seconds = 2562

# Pace in seconds per mile
pace_seconds_per_mile = time_seconds / distance_miles

print("Your average pace is", pace_seconds_per_mile, "seconds per mile")
# Out:
# Your average pace is 412.482 seconds per mile

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
int('101', 5)
# Out:
# 26

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
 x = y = 1

# %%
#4/3pi*r**3
radius = 5 #radius is in centimeter
volume = (4/3) * math.pi * (radius**3)
print(volume)
# Out:
# 523.5987755982989

# %%
rule = math.cos(x)**2 + math.sin(x)**2
x=int(input( "give me an x"))
if rule==1:
    print("The result was", rule, "The rule is true")
else:
    print("The result was", rule,"The rule is false")
# Out:
# give me an x42
# The result was 1.0 The rule is true

# %%
math.e**2
# Out:
# 7.3890560989306495

# %%
math.pow(math.e, 2)
# Out:
# 7.3890560989306495

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
def batman():
  return "I am Batman ( ◡̀_◡́)ᕤ"

# %%
def print_twice(string):
    print(string)
    print(string)

# %%
print_twice(batman())
# Out:
# I am Batman ( ◡̀_◡́)ᕤ
# I am Batman ( ◡̀_◡́)ᕤ

# %%
line = "batman, shadow of the nights"
print_twice(line)
# Out:
# batman, shadow of the nights
# batman, shadow of the nights

# %%
def repeat(word, n):
  print(word * n)

# %%
batman = "batman, "
def first_two_lines():
    (repeat(batman, 4))
    (repeat(batman, 4))

# %%
first_two_lines()
# Out:
# batman, batman, batman, batman,
# batman, batman, batman, batman,

# %%
def last_three_lines():
    repeat(batman, 2)
    print('(Lovely batman, Wonderful batman!)')
    repeat(batman, 2)

# %%
last_three_lines()
# Out:
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,

# %%
def print_verse():
    first_two_lines()
    last_three_lines()
print_verse()
# Out:
# batman, batman, batman, batman,
# batman, batman, batman, batman,
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,

# %%
for i in range(2):
  print("Verse", i)
  print_verse()
# Out:
# Verse 0
# batman, batman, batman, batman,
# batman, batman, batman, batman,
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,
# Verse 1
# batman, batman, batman, batman,
# batman, batman, batman, batman,
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,

# %%
n=3
def print_n_verses(n):
    for i in range(n):
        print_verse()

# %%
# Call the function to print 3 verses
print_n_verses(3)
# Out:
# batman, batman, batman, batman,
# batman, batman, batman, batman,
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,
# batman, batman, batman, batman,
# batman, batman, batman, batman,
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,
# batman, batman, batman, batman,
# batman, batman, batman, batman,
# batman, batman,
# (Lovely batman, Wonderful batman!)
# batman, batman,

# %%
def repeat(text, count):
    if count <= 0:
        return

    print(text)
    # The function calls itself to print the remaining repetitions
    repeat(text, count - 1)

print("Example 1")
repeat("Hello!", 3)

print("\nExample 2")
repeat("Python is fun.", 5)

print("\nExample 3")
repeat("Invisible", 0)

print("\nExample 4")
repeat("Error", -2)

print("\nExample 5")
repeat("Only once", 1)
# Out:
# Example 1
# Hello!
# Hello!
# Hello!
#
# Example 2
# Python is fun.
# Python is fun.
# Python is fun.
# Python is fun.
# Python is fun.
#
# Example 3
#
# Example 4
#
# Example 5
# Only once

# %%
#Write a function named print_right that takes a string named text as a parameter and prints the string with enough leading spaces,
#that the last letter of the string is in the 40th column of the display.

def print_right(string):
  a=len(string)
  b=40-a
  print(" "*b, string)
print_right("Monty")
print_right("Python's")
print_right("Flying Circus")
# Out:
#                                     Monty
#                                  Python's
#                             Flying Circus

# %% [markdown]
# triangle('L', 5)
# L
# LL
# LLL
# LLLL
# LLLLL

# %%
def triangle(word, n):
  for i in range(n+1):
    print(word*i)
triangle("L", 5)
# Out:
# L
# LL
# LLL
# LLLL
# LLLLL

# %% [markdown]
# rectangle('H', 5, 4)
# HHHHH
# HHHHH
# HHHHH
# HHHHH

# %%
def rectangle(word, n, j):
  for i in range(n+1):
    print(word*j)

# %%
rectangle("h",4,5)
# Out:
# hhhhh
# hhhhh
# hhhhh
# hhhhh
# hhhhh

# %% [markdown]
# 3.11.5. Exercise
# The song “99 Bottles of Beer” starts with this verse:
#
# 99 bottles of beer on the wall
# 99 bottles of beer
# Take one down, pass it around
# 98 bottles of beer on the wall
#
# Then the second verse is the same, except that it starts with 98 bottles and ends with 97. The song continues – for a very long time – until there are 0 bottles of beer.
#
# Write a function called bottle_verse that takes a number as a parameter and displays the verse that starts with the given number of bottles.
#
# Hint: Consider starting with a function that can print the first, second, or last line of the verse, and then use it to write bottle_verse.
#
# Use this function call to display the first verse.
#
# bottle_verse(99)
# 99 bottles of beer on the wall
# 99 bottles of beer
# Take one down, pass it around
# 98 bottles of beer on the wall
# If you want to print the whole song, you can use this for loop, which counts down from 99 to 1. You don’t have to completely understand this example—we’ll learn more about for loops and the range function later.
#
# for n in range(99, 0, -1):
#     bottle_verse(n)
#     print()

# %%
def bottle_verse(n):
  word_plural = "bottle" if n == 1 else "bottles"
  print(f"{n} {word_plural} of beer on the wall")
  print(f"{n} {word_plural} of beer")
  print("Take one down, pass it around")
  print(f"{n-1} {word_plural} of beer on the wall")
for n in range(99, 0, -1):
    bottle_verse(n)
    print()
# Out:
# 99 bottles of beer on the wall
# 99 bottles of beer
# Take one down, pass it around
# 98 bottles of beer on the wall
#
# 98 bottles of beer on the wall
# 98 bottles of beer
# Take one down, pass it around
# 97 bottles of beer on the wall
#
# 97 bottles of beer on the wall
# 97 bottles of beer
# Take one down, pass it around
# 96 bottles of beer on the wall
#
# 96 bottles of beer on the wall
# 96 bottles of beer
# Take one down, pass it around
# 95 bottles of beer on the wall
#
# 95 bottles of beer on the wall
# 95 bottles of beer
# Take one down, pass it around
# 94 bottles of beer on the wall
#
# 94 bottles of beer on the wall
# 94 bottles of beer
# Take one down, pass it around
# 93 bottles of beer on the wall
#
# 93 bottles of beer on the wall
# 93 bottles of beer
# Take one down, pass it around
# 92 bottles of beer on the wall
#
# 92 bottles of beer on the wall
# 92 bottles of beer
# Take one down, pass it around
# 91 bottles of beer on the wall
#
# ...
